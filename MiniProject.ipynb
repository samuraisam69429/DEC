# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(("/content/APY.csv"))
df
# Out:
#                              State District       Crop  Crop_Year  \
# 0       Andaman and Nicobar Island  NICOBARS  Arecanut       2007
# 1       Andaman and Nicobar Island  NICOBARS  Arecanut       2007
# 2       Andaman and Nicobar Island  NICOBARS  Arecanut       2008
# 3       Andaman and Nicobar Island  NICOBARS  Arecanut       2008
# 4       Andaman and Nicobar Island  NICOBARS  Arecanut       2009
# ...                            ...       ...       ...        ...
# 345331                 West Bengal   PURULIA     Wheat       2015
# 345332                 West Bengal   PURULIA     Wheat       2016
# 345333                 West Bengal   PURULIA     Wheat       2017
# 345334                 West Bengal   PURULIA     Wheat       2018
# 345335                 West Bengal   PURULIA     Wheat       2019
#
#              Season   Area   Production  Yield
# 0       Kharif       2439.6      3415.0   1.40
# 1       Rabi         1626.4      2277.0   1.40
# ...

# %% [markdown]
# # ***Preprocessing***

# %%
df.head()
# Out:
#                         State District       Crop  Crop_Year       Season  \
# 0  Andaman and Nicobar Island  NICOBARS  Arecanut       2007  Kharif
# 1  Andaman and Nicobar Island  NICOBARS  Arecanut       2007  Rabi
# 2  Andaman and Nicobar Island  NICOBARS  Arecanut       2008  Autumn
# 3  Andaman and Nicobar Island  NICOBARS  Arecanut       2008  Summer
# 4  Andaman and Nicobar Island  NICOBARS  Arecanut       2009  Autumn
#
#     Area   Production  Yield
# 0  2439.6      3415.0   1.40
# 1  1626.4      2277.0   1.40
# 2  4147.0      3060.0   0.74
# 3  4147.0      2660.0   0.64
# 4  4153.0      3120.0   0.75

# %%
df.shape
# Out:
# (345336, 8)

# %%
df.columns
# Out:
# Index(['State', 'District ', 'Crop', 'Crop_Year', 'Season', 'Area ',
#        'Production', 'Yield'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# State            0
# District         0
# Crop             9
# Crop_Year        0
# Season           0
# Area             0
# Production    4948
# Yield            0
# dtype: int64

# %%
df.mean()
# Out:
# <ipython-input-5-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Crop_Year       2008.887512
# Area           11671.467888
# Production    958472.639364
# Yield             79.423135
# dtype: float64

# %%
df.dtypes
# Out:
# State          object
# District       object
# Crop           object
# Crop_Year       int64
# Season         object
# Area          float64
# Production    float64
# Yield         float64
# dtype: object

# %%
Crop_Year=np.array(df['Crop_Year'])
Yield=np.array(df['Yield'])

# %%
plt.title("Crop_Year vs Yield")
plt.xlabel("Crop_Year")
plt.ylabel("Yield")
plt.bar(Crop_Year, Yield, color ='blue')
plt.show()

# %%
df['Production'].fillna(df['Production'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# State         0
# District      0
# Crop          9
# Crop_Year     0
# Season        0
# Area          0
# Production    0
# Yield         0
# dtype: int64

# %%
df['Yield'].fillna(df['Yield'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# State         0
# District      0
# Crop          0
# Crop_Year     0
# Cluster       0
# Season        0
# Area          0
# Production    0
# Yield         0
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#                              State District       Crop  Crop_Year  \
# 0       Andaman and Nicobar Island  NICOBARS  Arecanut       2007
# 1       Andaman and Nicobar Island  NICOBARS  Arecanut       2007
# 2       Andaman and Nicobar Island  NICOBARS  Arecanut       2008
# 3       Andaman and Nicobar Island  NICOBARS  Arecanut       2008
# 4       Andaman and Nicobar Island  NICOBARS  Arecanut       2009
# ...                            ...       ...       ...        ...
# 345331                 West Bengal   PURULIA     Wheat       2015
# 345332                 West Bengal   PURULIA     Wheat       2016
# 345333                 West Bengal   PURULIA     Wheat       2017
# 345334                 West Bengal   PURULIA     Wheat       2018
# 345335                 West Bengal   PURULIA     Wheat       2019
#
#              Season   Area   Production  Yield
# 0       Kharif       2439.6      3415.0   1.40
# 1       Rabi         1626.4      2277.0   1.40
# ...

# %%
APY=pd.read_csv("/content/APY.csv",header=None)
display(APY.head())
print(APY.shape)
# Out:
# <ipython-input-5-fa0dd58cc239>:1: DtypeWarning: Columns (3,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   APY=pd.read_csv("/content/APY.csv",header=None)
#                             0          1         2          3            4  \
# 0                       State  District       Crop  Crop_Year       Season
# 1  Andaman and Nicobar Island   NICOBARS  Arecanut       2007  Kharif
# 2  Andaman and Nicobar Island   NICOBARS  Arecanut       2007  Rabi
# 3  Andaman and Nicobar Island   NICOBARS  Arecanut       2008  Autumn
# 4  Andaman and Nicobar Island   NICOBARS  Arecanut       2008  Summer
#
#         5           6      7
# 0   Area   Production  Yield
# 1  2439.6        3415    1.4
# 2  1626.4        2277    1.4
# 3    4147        3060   0.74
# 4    4147        2660   0.64
# (345337, 8)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.describe()
# Out:
#            Crop_Year         Area     Production          Yield
# count  345336.000000  3.453360e+05  3.403880e+05  345336.000000
# mean     2008.887512  1.167147e+04  9.584726e+05      79.423135
# std         6.564361  4.584079e+04  2.153068e+07     916.678396
# min      1997.000000  4.000000e-03  0.000000e+00       0.000000
# 25%      2003.000000  7.400000e+01  8.700000e+01       0.550000
# 50%      2009.000000  5.320000e+02  7.170000e+02       1.000000
# 75%      2015.000000  4.112000e+03  7.182000e+03       2.470000
# max      2020.000000  8.580100e+06  1.597800e+09   43958.330000

# %%
df['Crop'].value_counts()
# Out:
# Rice                     21611
# Maize                    20513
# Moong(Green Gram)        15139
# Urad                     14581
# Sesamum                  13049
# Groundnut                12586
# Wheat                    11220
# Rapeseed &Mustard        11034
# Sugarcane                10942
# Arhar/Tur                10885
# Potato                   10756
# Onion                    10675
# Gram                     10474
# Jowar                     9769
# Dry chillies              8971
# Bajra                     8165
# Peas & beans (Pulses)     7266
# Sunflower                 7244
# Small millets             6985
# Cotton(lint)              6475
# Masoor                    6383
# Linseed                   5892
# Barley                    5891
# Ragi                      5757
# Sweet potato              5742
# Other Kharif pulses       5720
# Turmeric                  5607
# Horse-gram                5424
# Garlic                    5279
# Coriander                 5037
# ...

# %%
A=df.iloc[:,:-1] 
B=df.iloc[:,7].values
B = df[['Production']]
B
# Out:
#         Production
# 0           3415.0
# 1           2277.0
# 2           3060.0
# 3           2660.0
# 4           3120.0
# ...            ...
# 345331      1241.0
# 345332      2415.0
# 345333      2145.0
# 345334      2114.0
# 345335       931.0
#
# [345327 rows x 1 columns]

# %%
labelencoder_X=LabelEncoder()
A=A.apply(LabelEncoder().fit_transform)
A
# Out:
#         State  District   Crop  Crop_Year  Season  Area   Production
# 0           0        464     0         10       1   4294        3415
# 1           0        464     0         10       2   3303        2277
# 2           0        464     0         11       0   6219        3060
# 3           0        464     0         11       3   6219        2660
# 4           0        464     0         12       0   6227        3120
# ...       ...        ...   ...        ...     ...    ...         ...
# 345331     36        516    53         18       2   2254        1241
# 345332     36        516    53         19       2   2957        2415
# 345333     36        516    53         20       2   2534        2145
# 345334     36        516    53         21       2   2221        2114
# 345335     36        516    53         22       2   1667         931
#
# [345327 rows x 7 columns]

# %% [markdown]
# # ***Naive Bayes Classifiction***

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 345327 entries, 0 to 345335
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   State       345327 non-null  object
#  1   District    345327 non-null  object
#  2   Crop        345327 non-null  object
#  3   Crop_Year   345327 non-null  int64
#  4   Season      345327 non-null  object
#  5   Area        345327 non-null  float64
#  6   Production  345327 non-null  float64
#  7   Yield       345327 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 23.7+ MB

# %% [markdown]
# Create Dummy Variables

# %%
df.shape
# Out:
# (345327, 8)

# %%
X = df[['Production']]
Y = df[['Season']]

# %%
X
# Out:
#         Production
# 0           3415.0
# 1           2277.0
# 2           3060.0
# 3           2660.0
# 4           3120.0
# ...            ...
# 345331      1241.0
# 345332      2415.0
# 345333      2145.0
# 345334      2114.0
# 345335       931.0
#
# [345327 rows x 1 columns]

# %%
Y
# Out:
#              Season
# 0       Kharif
# 1       Rabi
# 2       Autumn
# 3       Summer
# 4       Autumn
# ...             ...
# 345331  Rabi
# 345332  Rabi
# 345333  Rabi
# 345334  Rabi
# 345335  Rabi
#
# [345327 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.25,random_state=42)
len(x_train),len(x_test),len(y_train),len(y_test)
# Out:
# (258995, 86332, 258995, 86332)

# %%
x_train
# Out:
#           Production
# 52813   1.200000e+01
# 293898  1.350000e+02
# 273135  3.160000e+02
# 83914   6.330000e+04
# 294182  2.100000e+01
# ...              ...
# 119879  7.000000e+00
# 259178  8.420000e+07
# 131932  1.400000e+01
# 146867  9.584726e+05
# 121958  1.130000e+02
#
# [258995 rows x 1 columns]

# %%
x_test
# Out:
#         Production
# 161022         5.0
# 18177       4528.0
# 42672          9.0
# 162519     16622.0
# 33546      75333.0
# ...            ...
# 276940    123884.0
# 342629       527.0
# 243831        40.0
# 330679       166.0
# 64573       2299.0
#
# [86332 rows x 1 columns]

# %%
y_train
# Out:
#              Season
# 52813   Rabi
# 293898  Kharif
# 273135  Whole Year
# 83914   Whole Year
# 294182  Kharif
# ...             ...
# 119879  Kharif
# 259178  Whole Year
# 131932  Kharif
# 146867  Whole Year
# 121958  Rabi
#
# [258995 rows x 1 columns]

# %%
y_test
# Out:
#              Season
# 161022  Rabi
# 18177   Kharif
# 42672   Whole Year
# 162519  Kharif
# 33546   Winter
# ...             ...
# 276940  Rabi
# 342629  Summer
# 243831  Kharif
# 330679  Rabi
# 64573   Kharif
#
# [86332 rows x 1 columns]

# %%
naive=GaussianNB()
naive_model=naive.fit(x_train,y_train)
naive_model
print('The model has ran Successfully!!!')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The model has ran Successfully!!!

# %%
y_test['Predicted_Season'] = naive_model.predict(x_test)

# %%
y_test
# Out:
#              Season Predicted_Season
# 161022  Rabi             Rabi
# 18177   Kharif           Rabi
# 42672   Whole Year       Rabi
# 162519  Kharif           Rabi
# 33546   Winter           Rabi
# ...             ...              ...
# 276940  Rabi             Rabi
# 342629  Summer           Rabi
# 243831  Kharif           Rabi
# 330679  Rabi             Rabi
# 64573   Kharif           Rabi
#
# [86332 rows x 2 columns]

# %%
print(confusion_matrix(y_test['Season'],y_test['Predicted_Season']))
# Out:
# [[    0     6  1825     0     0     0]
#  [    0  1706 32739     0   122     0]
#  [    0  1254 23804     0    30     0]
#  [    0    89  5494     0     0     0]
#  [    0  1020 15323     0   859     0]
#  [    0   172  1888     0     1     0]]

# %%
accuracy_Season= accuracy_score(y_test['Season'],y_test['Predicted_Season'])
accuracy_Season = np.round(accuracy_Season,2)
print('The Accuracy of Naive Bays Calssification model is: ',accuracy_Season)
# Out:
# The Accuracy of Naive Bays Calssification model is:  0.31

# %% [markdown]
# # ***Decision Tree Classification***

# %%
from six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus

# %%
regressor = DecisionTreeClassifier(criterion = 'gini',max_depth=5,splitter='best')
regressor.fit(X,Y)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
dot_data=StringIO()
feature_cols=['State','Dsitrict','Crop','Crop_Year','Season','Area','Production','Yield']
export_graphviz(regressor, out_file=dot_data,filled=True,rounded=True,special_characters=True,feature_names=feature_cols,class_names=['0','1'])
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-411-964b8287801e> in <cell line: 3>()
#       1 dot_data=StringIO()
#       2 feature_cols=['State','Dsitrict','Crop','Crop_Year','Season','Area','Production','Yield']
# ----> 3 export_graphviz(regressor, out_file=dot_data,filled=True,rounded=True,special_characters=True,feature_names=feature_cols,class_names=['0','1'])
#       4 graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
#       5 Image(graph.create_png())
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     886             fontname=fontname,
#     887         )
# --> 888         exporter.export(decision_tree)
#     889
# ...

# %% [markdown]
# # ***K-means Clustering Algorithm***

# %%
ssd = []
for k in range(2,9):
    kmeans_model = KMeans(n_clusters=k)
    kmeans_model.fit(X)
    ssd.append(kmeans_model.inertia_)
plt.figure(figsize=(6,4), dpi=100)
plt.plot(range(2,9),ssd,color='green',marker='o')
plt.xlabel("Number of Clusters (K)")
plt.ylabel("SSD for K")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)
kmeans_model = KMeans(n_clusters=3)
clusters = kmeans_model.fit_predict(scaled_X)
clusters
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
df.insert(df.columns.get_loc("Season"),"Cluster",clusters)
df
# Out:
#                              State District       Crop  Crop_Year  Cluster  \
# 0       Andaman and Nicobar Island  NICOBARS  Arecanut       2007        0
# 1       Andaman and Nicobar Island  NICOBARS  Arecanut       2007        0
# 2       Andaman and Nicobar Island  NICOBARS  Arecanut       2008        0
# 3       Andaman and Nicobar Island  NICOBARS  Arecanut       2008        0
# 4       Andaman and Nicobar Island  NICOBARS  Arecanut       2009        0
# ...                            ...       ...       ...        ...      ...
# 345331                 West Bengal   PURULIA     Wheat       2015        0
# 345332                 West Bengal   PURULIA     Wheat       2016        0
# 345333                 West Bengal   PURULIA     Wheat       2017        0
# 345334                 West Bengal   PURULIA     Wheat       2018        0
# 345335                 West Bengal   PURULIA     Wheat       2019        0
#
#              Season   Area   Production  Yield
# ...

# %%
df.drop(['Cluster'], axis=1, inplace=True)
# Out:
# <ipython-input-373-62c8774a6745>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['Cluster'], axis=1, inplace=True)

# %%
df["Cluster"].value_counts()
# Out:
# 0    344740
# 2       404
# 1       183
# Name: Cluster, dtype: int64

# %% [markdown]
# chutiya hu mei

# %%
Y=df[['Yield']]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
import numpy as np

# %%
X_a = np.array(X)
X = X_a.reshape((-1,1))
Y_a = np.array(y)
y = Y_a.reshape((-1,1))

# %%
clf = DecisionTreeRegressor()

# Fit the classifier to the training data
clf.fit(x_train, y_train)

# Predict the class labels of the testing data
y_pred = clf.predict(x_test)

# Calculate the accuracy of the classifier
accuracy = r2_score(y_test, y_pred)
print("accuracy: ", accuracy)
# Out:
# accuracy:  0.2926001772969058

# %%
clf = RandomForestRegressor()

# Fit the classifier to the training data
clf.fit(x_train, y_train)

# Predict the class labels of the testing data
y_pred = clf.predict(x_test)

# Calculate the accuracy of the classifier
accuracy = r2_score(y_test, y_pred)
print("accuracy: ", accuracy)
# Out:
# <ipython-input-420-dc868261c65b>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(x_train, y_train)
# accuracy:  0.4390250423600047

# %%
x_train
# Out:
#           Production
# 52813   1.200000e+01
# 293898  1.350000e+02
# 273135  3.160000e+02
# 83914   6.330000e+04
# 294182  2.100000e+01
# ...              ...
# 119879  7.000000e+00
# 259178  8.420000e+07
# 131932  1.400000e+01
# 146867  9.584726e+05
# 121958  1.130000e+02
#
# [258995 rows x 1 columns]
